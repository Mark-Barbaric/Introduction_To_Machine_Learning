# %% [markdown]
# # 1. Using data frames for pre-processing data #
#
# This notebook introduces you to pandas in Python. Using pandas you will learn how to pre-process your data for machine learning.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.1 Writing to data frames ##
#
# If you want to create a data frame, you can do the following.

# %%
df = pd.DataFrame({
   'col1': ['Item0', 'Item0', 'Item1', 'Item1'],
   'col2': ['Gold', 'Bronze', 'Gold', 'Silver'],
   'col3': [1, 2, np.nan, 4]
})

# %%
print(df)
# Out:
#     col1    col2  col3
# 0  Item0    Gold   1.0
# 1  Item0  Bronze   2.0
# 2  Item1    Gold   NaN
# 3  Item1  Silver   4.0

# %%
# The file you're reading must be in the same directory on your computer as this notebook, or you must specify the file path 

countries = pd.read_csv('countries of the world .csv', sep=',', thousands=',')

# %%
print(countries)
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...

# %%
#show first five rows of the df 

countries.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                         480                             0
# 1           28748                        1246                           126
# 2         2381740                         138                             4
# 3             199                        2904                          5829
# 4             468                        1521                             0
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
#statistics on the numerical columns 

countries.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  2.270000e+02    2.270000e+02                  227.000000
# mean   2.874028e+07    5.982270e+05                 3790.471366
# std    1.178913e+08    1.790282e+06                16601.858246
# min    7.026000e+03    2.000000e+00                    0.000000
# 25%    4.376240e+05    4.647500e+03                  291.500000
# 50%    4.786994e+06    8.660000e+04                  788.000000
# 75%    1.749777e+07    4.418110e+05                 1901.500000
# max    1.313974e+09    1.707520e+07               162715.000000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    227.000000     224.000000
# mean                    2116.533040      12.129464
# std                     7228.686315     477.016425
# min                        0.000000   -2099.000000
# 25%                       10.000000     -68.000000
# 50%                       73.000000       0.000000
# ...

# %%
#shape of the df 

countries.shape
# Out:
# (227, 20)

# %%
#columns and their data type 

countries.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)              int64
# Coastline (coast/area ratio)            int64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %% [markdown]
# ## 1.3 Selecting data ##

# %%
#Select column by name 

countries["Country"]
# Out:
# 0               Afghanistan
# 1                   Albania
# 2                   Algeria
# 3            American Samoa
# 4                   Andorra
# 5                    Angola
# 6                  Anguilla
# 7         Antigua & Barbuda
# 8                 Argentina
# 9                   Armenia
# 10                    Aruba
# 11                Australia
# 12                  Austria
# 13               Azerbaijan
# 14             Bahamas, The
# 15                  Bahrain
# 16               Bangladesh
# 17                 Barbados
# 18                  Belarus
# 19                  Belgium
# 20                   Belize
# 21                    Benin
# 22                  Bermuda
# 23                   Bhutan
# 24                  Bolivia
# 25     Bosnia & Herzegovina
# 26                 Botswana
# 27                   Brazil
# 28       British Virgin Is.
# 29                   Brunei
#                ...
# 197                   Syria
# 198                  Taiwan
# ...

# %%
# selecting another way 

countries.Country
# Out:
# 0               Afghanistan
# 1                   Albania
# 2                   Algeria
# 3            American Samoa
# 4                   Andorra
# 5                    Angola
# 6                  Anguilla
# 7         Antigua & Barbuda
# 8                 Argentina
# 9                   Armenia
# 10                    Aruba
# 11                Australia
# 12                  Austria
# 13               Azerbaijan
# 14             Bahamas, The
# 15                  Bahrain
# 16               Bangladesh
# 17                 Barbados
# 18                  Belarus
# 19                  Belgium
# 20                   Belize
# 21                    Benin
# 22                  Bermuda
# 23                   Bhutan
# 24                  Bolivia
# 25     Bosnia & Herzegovina
# 26                 Botswana
# 27                   Brazil
# 28       British Virgin Is.
# 29                   Brunei
#                ...
# 197                   Syria
# 198                  Taiwan
# ...

# %%
countries[["Country", "GDP ($ per capita)"]]
# Out:
#                    Country  GDP ($ per capita)
# 0             Afghanistan                700.0
# 1                 Albania               4500.0
# 2                 Algeria               6000.0
# 3          American Samoa               8000.0
# 4                 Andorra              19000.0
# 5                  Angola               1900.0
# 6                Anguilla               8600.0
# 7       Antigua & Barbuda              11000.0
# 8               Argentina              11200.0
# 9                 Armenia               3500.0
# 10                  Aruba              28000.0
# 11              Australia              29000.0
# 12                Austria              30000.0
# 13             Azerbaijan               3400.0
# 14           Bahamas, The              16700.0
# 15                Bahrain              16900.0
# 16             Bangladesh               1900.0
# 17               Barbados              15700.0
# 18                Belarus               6100.0
# ...

# %%
#selecting by position in df

#select first row
countries.iloc[0]

#select first column
countries.iloc[:,0]

#select first four rows and first two columns
countries.iloc[0:4, 0:2]
# Out:
#            Country                               Region
# 0     Afghanistan         ASIA (EX. NEAR EAST)
# 1         Albania   EASTERN EUROPE
# 2         Algeria   NORTHERN AFRICA
# 3  American Samoa   OCEANIA

# %%
#select by condition
countries[countries['Population'] == 31056997]
# Out:
#         Country                         Region  Population  Area (sq. mi.)  \
# 0  Afghanistan   ASIA (EX. NEAR EAST)             31056997          647500
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                         480                             0         2306.0
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                             16307.0               700.0         360.0
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 0               32.0      1213.0       22.0     8765.0      1.0      466.0
#
#    Deathrate  Agriculture  Industry  Service
# 0     2034.0         38.0      24.0     38.0

# %%
countries[countries['Country'] == 'Afghanistan ']
# Out:
#         Country                         Region  Population  Area (sq. mi.)  \
# 0  Afghanistan   ASIA (EX. NEAR EAST)             31056997          647500
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                         480                             0         2306.0
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                             16307.0               700.0         360.0
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 0               32.0      1213.0       22.0     8765.0      1.0      466.0
#
#    Deathrate  Agriculture  Industry  Service
# 0     2034.0         38.0      24.0     38.0

# %%
# see unique values in a column 
countries.Country.unique()
# Out:
# array(['Afghanistan ', 'Albania ', 'Algeria ', 'American Samoa ',
#        'Andorra ', 'Angola ', 'Anguilla ', 'Antigua & Barbuda ',
#        'Argentina ', 'Armenia ', 'Aruba ', 'Australia ', 'Austria ',
#        'Azerbaijan ', 'Bahamas, The ', 'Bahrain ', 'Bangladesh ',
#        'Barbados ', 'Belarus ', 'Belgium ', 'Belize ', 'Benin ',
#        'Bermuda ', 'Bhutan ', 'Bolivia ', 'Bosnia & Herzegovina ',
#        'Botswana ', 'Brazil ', 'British Virgin Is. ', 'Brunei ',
#        'Bulgaria ', 'Burkina Faso ', 'Burma ', 'Burundi ', 'Cambodia ',
#        'Cameroon ', 'Canada ', 'Cape Verde ', 'Cayman Islands ',
#        'Central African Rep. ', 'Chad ', 'Chile ', 'China ', 'Colombia ',
#        'Comoros ', 'Congo, Dem. Rep. ', 'Congo, Repub. of the ',
#        'Cook Islands ', 'Costa Rica ', "Cote d'Ivoire ", 'Croatia ',
#        'Cuba ', 'Cyprus ', 'Czech Republic ', 'Denmark ', 'Djibouti ',
#        'Dominica ', 'Dominican Republic ', 'East Timor ', 'Ecuador ',
# ...

# %%
#selecting by parts of a string
countries[countries['Country'].str.contains("Al")]
# Out:
#     Country                               Region  Population  Area (sq. mi.)  \
# 1  Albania   EASTERN EUROPE                          3581655           28748
# 2  Algeria   NORTHERN AFRICA                        32930091         2381740
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 1                        1246                           126         -493.0
# 2                         138                             4          -39.0
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 1                              2152.0              4500.0         865.0
# 2                                31.0              6000.0         700.0
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 1              712.0      2109.0      442.0     7449.0      3.0     1511.0
# 2              781.0       322.0       25.0     9653.0      1.0     1714.0
#
#    Deathrate  Agriculture  Industry  Service
# ...

# %%
# selecting by several conditions 
countries[(countries["Region"]=="NORTHERN AFRICA                    ") & (countries["GDP ($ per capita)"] >6000)]
# Out:
#       Country                               Region  Population  \
# 118    Libya   NORTHERN AFRICA                         5900754
# 205  Tunisia   NORTHERN AFRICA                        10175014
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 118         1759540                          34                            10
# 205          163610                         622                            70
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 118            0.0                               246.0              6400.0
# 205          -57.0                              2477.0              6900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 118         826.0             1271.0       103.0       19.0     9878.0
# 205         742.0             1236.0      1786.0     1374.0      684.0
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# ...

# %%
countries["Region"].unique()

countries['Region'] = countries['Region'].str.strip()
countries[countries["Region"]=="EASTERN EUROPE"]
# Out:
#                    Country          Region  Population  Area (sq. mi.)  \
# 1                 Albania   EASTERN EUROPE     3581655           28748
# 25   Bosnia & Herzegovina   EASTERN EUROPE     4498976           51129
# 30               Bulgaria   EASTERN EUROPE     7385367          110910
# 50                Croatia   EASTERN EUROPE     4494749           56542
# 53         Czech Republic   EASTERN EUROPE    10235455           78866
# 92                Hungary   EASTERN EUROPE     9981334           93030
# 123             Macedonia   EASTERN EUROPE     2050554           25333
# 163                Poland   EASTERN EUROPE    38536869          312685
# 168               Romania   EASTERN EUROPE    22303552          237500
# 181                Serbia   EASTERN EUROPE     9396411           88361
# 185              Slovakia   EASTERN EUROPE     5439448           48845
# 186              Slovenia   EASTERN EUROPE     2010347           20273
#
# ...

# %%
#selecting using .isin - just another way to select 
countries[countries['Region'].isin(['EASTERN EUROPE','WESTERN EUROPE'])]
# Out:
#                    Country          Region  Population  Area (sq. mi.)  \
# 1                 Albania   EASTERN EUROPE     3581655           28748
# 4                 Andorra   WESTERN EUROPE       71201             468
# 12                Austria   WESTERN EUROPE     8192880           83870
# 19                Belgium   WESTERN EUROPE    10379067           30528
# 25   Bosnia & Herzegovina   EASTERN EUROPE     4498976           51129
# 30               Bulgaria   EASTERN EUROPE     7385367          110910
# 50                Croatia   EASTERN EUROPE     4494749           56542
# 53         Czech Republic   EASTERN EUROPE    10235455           78866
# 54                Denmark   WESTERN EUROPE     5450661           43094
# 66          Faroe Islands   WESTERN EUROPE       47246            1399
# 68                Finland   WESTERN EUROPE     5231372          338145
# 69                 France   WESTERN EUROPE    60876136          547030
# ...

# %% [markdown]
# ## 1.4 Creating new data ##

# %% [markdown]
# ## 1.2 Reading files to data frames ##
#
# How you read data files will depend on the input format. We will be using csv (comma seperated value) files, but if you want something else later, google is your friend.

# %% [markdown]
# ## 1.5 Sorting in df  ##

# %%
#sort by index

countries.sort_index(axis=1, ascending=False)
# Out:
#      Service                Region  Population  Pop. Density (per sq. mi.)  \
# 0       38.0  ASIA (EX. NEAR EAST)    31056997                         480
# 1      579.0        EASTERN EUROPE     3581655                        1246
# 2      298.0       NORTHERN AFRICA    32930091                         138
# 3        NaN               OCEANIA       57794                        2904
# 4        NaN        WESTERN EUROPE       71201                        1521
# 5      246.0    SUB-SAHARAN AFRICA    12127071                          97
# 6       78.0   LATIN AMER. & CARIB       13477                        1321
# 7      743.0   LATIN AMER. & CARIB       69108                        1560
# 8      547.0   LATIN AMER. & CARIB    39921833                         144
# 9      418.0   C.W. OF IND. STATES     2976372                         999
# 10     663.0   LATIN AMER. & CARIB       71891                        3725
# ...

# %%
#sort by values in a column 
countries.sort_values(by='Region')
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 34         Cambodia         ASIA (EX. NEAR EAST)             13881427
# 42            China         ASIA (EX. NEAR EAST)           1313973713
# 58       East Timor         ASIA (EX. NEAR EAST)              1062777
# 91        Hong Kong         ASIA (EX. NEAR EAST)              6940432
# 94            India         ASIA (EX. NEAR EAST)           1095351995
# 95        Indonesia         ASIA (EX. NEAR EAST)            245452739
# 96             Iran         ASIA (EX. NEAR EAST)             68688433
# 103           Japan         ASIA (EX. NEAR EAST)            127463611
# 109    Korea, North         ASIA (EX. NEAR EAST)             23113019
# 110    Korea, South         ASIA (EX. NEAR EAST)             48846823
# 32            Burma         ASIA (EX. NEAR EAST)             47382633
# ...

# %% [markdown]
# ## 1.6 Summing by condition ##

# %%
#name a new df
Europe  =countries[countries['Region'].isin(['EASTERN EUROPE                     ','WESTERN EUROPE                     '])]

# %%
Europe.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  4.000000e+01       40.000000                   40.000000
# mean   1.290637e+07   121567.500000                 6967.000000
# std    2.015897e+07   153312.985805                26076.371928
# min    2.792800e+04        2.000000                   29.000000
# 25%    3.750075e+05     2289.250000                  809.750000
# 50%    5.335410e+06    53835.500000                 1190.500000
# 75%    1.043577e+07   158330.000000                 2170.250000
# max    8.242230e+07   547030.000000               162715.000000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                     40.000000      40.000000
# mean                    1849.000000     192.600000
# std                     4447.836512     300.555452
# min                        0.000000    -493.000000
# 25%                        0.000000      57.250000
# 50%                       69.500000     162.500000
# ...

# %%
Europe.head()
# Out:
#                   Country                               Region  Population  \
# 1                Albania   EASTERN EUROPE                          3581655
# 4                Andorra   WESTERN EUROPE                            71201
# 12               Austria   WESTERN EUROPE                          8192880
# 19               Belgium   WESTERN EUROPE                         10379067
# 25  Bosnia & Herzegovina   EASTERN EUROPE                          4498976
#
#     Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 1            28748                        1246                           126
# 4              468                        1521                             0
# 12           83870                         977                             0
# 19           30528                        3400                            22
# 25           51129                         880                             4
#
# ...

# %%
countries["PopGrowth"] = countries["Birthrate"]-countries["Deathrate"]
countries
# Out:
#                    Country                Region  Population  Area (sq. mi.)  \
# 0             Afghanistan   ASIA (EX. NEAR EAST)    31056997          647500
# 1                 Albania         EASTERN EUROPE     3581655           28748
# 2                 Algeria        NORTHERN AFRICA    32930091         2381740
# 3          American Samoa                OCEANIA       57794             199
# 4                 Andorra         WESTERN EUROPE       71201             468
# 5                  Angola     SUB-SAHARAN AFRICA    12127071         1246700
# 6                Anguilla    LATIN AMER. & CARIB       13477             102
# 7       Antigua & Barbuda    LATIN AMER. & CARIB       69108             443
# 8               Argentina    LATIN AMER. & CARIB    39921833         2766890
# 9                 Armenia    C.W. OF IND. STATES     2976372           29800
# 10                  Aruba    LATIN AMER. & CARIB       71891             193
# ...

# %% [markdown]
# ## 1.7 Handling NaN ##

# %%
# Are there NaN? 

countries.isnull().values.any()
# Out:
# True

# %%
# Find the NaNs
countries[countries.isnull().any(1)]
countries[countries.isnull().any(1)].sum()
# Out:
# Country                               American Samoa Andorra Bosnia & Herzegovina Co...
# Region                                OCEANIAWESTERN EUROPEEASTERN EUROPEOCEANIANEAR...
# Population                                                                     29277798
# Area (sq. mi.)                                                                  2713444
# Pop. Density (per sq. mi.)                                                       305614
# Coastline (coast/area ratio)                                                     177121
# Net migration                                                                      1908
# Infant mortality (per 1000 births)                                                37499
# GDP ($ per capita)                                                               356300
# Literacy (%)                                                                      13732
# Phones (per 1000)                                                                113896
# ...

# %%
#Remove Wallis and Futuna from data

countries_woWF = countries[countries["Country"] != "Wallis and Futuna "]

countries.dropna(subset=["Climate"])

climateMedian = countries["Climate"].median()
countries["Climate"].fillna(climateMedian, inplace=True)

# %%
# find means of columns by region

lookup_means = countries.groupby(["Region"]).mean()
lookup_means
# Out:
#                                        Population  Area (sq. mi.)  \
# Region
# ASIA (EX. NEAR EAST)                 1.317137e+08    8.248826e+05
# BALTICS                              2.394991e+06    5.833833e+04
# C.W. OF IND. STATES                  2.334013e+07    1.841737e+06
# EASTERN EUROPE                       9.992893e+06    9.601850e+04
# LATIN AMER. & CARIB                  1.248499e+07    4.565352e+05
# NEAR EAST                            1.219177e+07    2.722241e+05
# NORTHERN AFRICA                      2.690119e+07    1.003148e+06
# NORTHERN AMERICA                     6.633446e+07    4.356494e+06
# OCEANIA                              1.577698e+06    4.057053e+05
# SUB-SAHARAN AFRICA                   1.469484e+07    4.772825e+05
# WESTERN EUROPE                       1.415500e+07    1.325171e+05
#
#                                      Pop. Density (per sq. mi.)  \
# Region
# ASIA (EX. NEAR EAST)                               12648.250000
# ...

# %% [markdown]
# ## 1.8 Plotting data ##

# %%
plt.plot(countries.Population, countries["Area (sq. mi.)"], "kx")
plt.title("Area vs. Poulation")
plt.xlabel("Population")
plt.ylabel("Area (sq. mi)")
# Out:
# Text(0,0.5,'Area (sq. mi)')

# %%
LitGDP = countries[["Literacy (%)", "GDP ($ per capita)"]]

# %%
LitGDP_woNA = LitGDP.dropna()

# %%
np.corrcoef(LitGDP_woNA["Literacy (%)"], LitGDP_woNA["GDP ($ per capita)"])
# Out:
# array([[1.        , 0.51314354],
#        [0.51314354, 1.        ]])

# %%
countries[(countries["Population"]>10**6) & (countries["Net migration"]>50)]
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 11              Australia   OCEANIA                                20264082
# 18                Belarus                  C.W. OF IND. STATES     10293011
# 19                Belgium   WESTERN EUROPE                         10379067
# 36                 Canada   NORTHERN AMERICA                       33098932
# 48             Costa Rica               LATIN AMER. & CARIB         4075261
# 50                Croatia   EASTERN EUROPE                          4494749
# 53         Czech Republic   EASTERN EUROPE                         10235455
# 54                Denmark   WESTERN EUROPE                          5450661
# 68                Finland   WESTERN EUROPE                          5231372
# ...

# %%
countries[(countries["Population"]>10**6)]
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 11              Australia   OCEANIA                                20264082
# 12                Austria   WESTERN EUROPE                          8192880
# 13             Azerbaijan                  C.W. OF IND. STATES      7961619
# 16             Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 18                Belarus                  C.W. OF IND. STATES     10293011
# ...

# %%
countries['New'] = [1 if  x>10**6 else 0 for (x,y) in tmp]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-89d001873bdf> in <module>()
# ----> 1 countries['New'] = [1 if  x>10**6 else 0 for (x,y) in tmp]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3386
#    3387             # turn me into an ndarray
# ...

# %%
countries
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...

# %%
two = countries[["Population", "Net migration"]]

# %%
zip(two)

# %%
tmp = zip(countries.Population, countries.Climate)

# %%
def condition(row): 
    value = 0
    if row["Population"]>10**6: 
        value = 1
    elif row["Net migration"]>50: 
        value = 1
    return value

# %%
countries["new"] = countries.apply(lambda row: condition(row), axis=1)

# %%
countries
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...
